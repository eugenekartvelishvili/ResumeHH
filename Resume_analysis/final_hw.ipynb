# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь

df = pd.read_csv("C:/Users/ekart/OneDrive/Рабочий стол/final_hw_python/dst-3.0_16_1_hh_database.csv", sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь

# Вывод первых нескольких строк
display(df.head())

# Вывод последних нескольких строк
display(df.tail())
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %%
# Уникальные значения
df.nunique()
# Out:
# Пол, возраст                       16003
# ЗП                                   690
# Ищет работу на должность:          14929
# Город, переезд, командировки       10063
# Занятость                             38
# График                                47
# Опыт работы                        44413
# Последнее/нынешнее место работы    30214
# Последняя/нынешняя должность       16927
# Образование и ВУЗ                  40148
# Обновление резюме                  18838
# Авто                                   2
# dtype: int64

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
# Число пропущенных значений
df.isnull().sum()
# Out:
# Пол, возраст                         0
# ЗП                                   0
# Ищет работу на должность:            0
# Город, переезд, командировки         0
# Занятость                            0
# График                               0
# Опыт работы                        168
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Образование и ВУЗ                    0
# Обновление резюме                    0
# Авто                                 0
# dtype: int64

# %%
# Основная информация по данным
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# Тип данных object

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь

df.count()
# Out:
# Пол, возраст                       44744
# ЗП                                 44744
# Ищет работу на должность:          44744
# Город, переезд, командировки       44744
# Занятость                          44744
# График                             44744
# Опыт работы                        44576
# Последнее/нынешнее место работы    44743
# Последняя/нынешняя должность       44742
# Образование и ВУЗ                  44744
# Обновление резюме                  44744
# Авто                               44744
# dtype: int64

# %% [markdown]
# Количество непустых значений равно 44744

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# Самая популярная вакансия - Системный администратор

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
def extract_education(text):
    # Извлекаем первые два слова
    words = text.split()[:2]
    
    # Объединяем слова для упрощения сопоставления
    edu_str = ' '.join(words).lower()
    
    # Определяем категории
    if 'неоконченное высшее' in edu_str:
        return 'неоконченное высшее'
    elif 'высшее' in edu_str:
        return 'высшее'
    elif 'среднее специальное' in edu_str:
        return 'среднее специальное'
    elif 'среднее' in edu_str:
        return 'среднее'
    else:
        return 'Неопределенное'

# Создаем новый столбец 'Образование'
df['Образование'] = df['Образование и ВУЗ'].apply(extract_education)

# %%
# Удаляем столбец 'Образование и ВУЗ'
df.drop('Образование и ВУЗ', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %%
# Проверяем уникальные значения в новом столбце 'Образование'
print(df['Образование'].unique())
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']

# %%
# Количество значений
df['Образование'].value_counts()
# Out:
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: Образование, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Функция для извлечения пола
def extract_gender(text):
    if 'Мужчина' in text:
        return 'М'
    elif 'Женщина' in text:
        return 'Ж'
    else:
        return 'Неопределенный'

# Функция для извлечения возраста
def extract_age(text):
    # Извлекаем возраст как число
    age_parts = text.split(',')[1]  # Возраст - это второй элемент после разделения
    age = ''.join(filter(str.isdigit, age_parts))  # Удаляем нецифровые символы
    return int(age) if age else None

# Создаем новые столбцы
df['Пол'] = df['Пол, возраст'].apply(extract_gender)
df['Возраст'] = df['Пол, возраст'].apply(extract_age)

# Удаляем старый столбец
df.drop('Пол, возраст', axis=1, inplace=True)

# Проверка результатов
print(df['Пол'].unique())
print(df['Возраст'].unique())
# Out:
# ['М' 'Ж']
# [ 39  60  36  38  26  29  46  34  35  59  27  21  31  37  30  33  42  32
#   23  28  25  24  43  53  49  44  48  54  22  20  40  62  72  45  41  61
#   50  58  57  52  56  18  19  51  16  47  71  63  55  64  68  17  73  66
#   65  77  67  69  76  70  14  15 100]

# %%
# Подсчет количества женских резюме
female_resumes = df[df['Пол'] == 'Ж'].shape[0]

# Расчет процента
percentage_female = (female_resumes / df.shape[0]) * 100

# Вывод результата, округленного до двух знаков после запятой
percentage_female_rounded = round(percentage_female, 2)

percentage_female_rounded
# Out:
# 19.07

# %%
# Вычисление среднего возраста
average_age = df['Возраст'].mean()

# Округление результата до одного десятичного знака
average_age_rounded = round(average_age, 1)

average_age_rounded
# Out:
# 32.2

# %%
df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
df['Опыт работы']
# Out:
# 0        Опыт работы 16 лет 10 месяцев  Август 2010 — п...
# 1        Опыт работы 19 лет 5 месяцев  Январь 2000 — по...
# 2        Опыт работы 10 лет 3 месяца  Октябрь 2004 — Де...
# 3        Опыт работы 18 лет 9 месяцев  Август 2017 — Ап...
# 4        Опыт работы 5 лет 7 месяцев  Региональный мене...
#                                ...
# 44739    Опыт работы 7 лет 7 месяцев  Финансист, аналит...
# 44740    Опыт работы 7 лет  Системный администратор, IT...
# 44741    Опыт работы 21 год 5 месяцев  Январь 1998 — по...
# 44742    Опыт работы 3 года 10 месяцев  Контент-менедже...
# 44743    Опыт работы 15 лет 10 месяцев  Руководитель пр...
# Name: Опыт работы, Length: 44744, dtype: object

# %%
def extract_experience_with_split_method(experience_text):
    # пропущенные значения и 'Не указано'
    if experience_text == np.nan or experience_text == 'Не указано' or type(experience_text) is float: 
        total_months = np.nan
        
    else:
        # сплит текста с двумя пробелами
        experience_part = experience_text.split('  ')[0]

        # обычный сплит
        experience_elements = experience_part.split()

        # получаем нужные элементы игнорияуя первые два известных слова
        relevant_elements = experience_elements[2:]

        # Iинициализируем год и месяц
        years = 0
        months = 0

        # Check the number of elements and extract years and months accordingly
        if len(relevant_elements) == 2:
            # Only one number present, check if it's years or months
            if relevant_elements[1] in ["год", "года", "лет"]:
                years = int(relevant_elements[0])
            else: 
                months = int(relevant_elements[0])
        if len(relevant_elements) == 4:
            # и год и месяц
            years = int(relevant_elements[0])
            months = int(relevant_elements[2])

        # общий опыт работы в месяцах
        total_months = years * 12 + months
        return total_months

# прмиеним функцию
df['Опыт работы (месяц)'] = df['Опыт работы'].apply(extract_experience_with_split_method)

# Recalculate the median and maximum experience in months for the updated dataset
median_experience_split_method = df['Опыт работы (месяц)'].median()
max_experience_split_method = df['Опыт работы (месяц)'].max()

median_experience_split_method, max_experience_split_method
# Out:
# (100.0, 1188.0)

# %%
df.drop('Опыт работы', axis=1, inplace=True)

# %%
df['Опыт работы (месяц)']
# Out:
# 0        202.0
# 1        233.0
# 2        123.0
# 3        225.0
# 4         67.0
#          ...
# 44739     91.0
# 44740     84.0
# 44741    257.0
# 44742     46.0
# 44743    190.0
# Name: Опыт работы (месяц), Length: 44744, dtype: float64

# %%
df['Опыт работы (месяц)'].isnull().sum()
# Out:
# 170

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# #ваш код здесь

# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ] 
def city_reloc_trip(input_string): 
    reloc = False 
    trip = False 
    info_strings = input_string.split(' , ') 
    if info_strings[0] in million_cities: 
        city = 'город-миллионник' 
    elif info_strings[0] == 'Москва': 
        city = 'Москва' 
    elif info_strings[0] == 'Санкт-Петербург': 
        city = 'Санкт-Петербург' 
    else: 
        city = 'другие' 
    if 'перее' not in info_strings[1]: 
        info_strings.pop(1) 
    if info_strings[1].split()[0] != 'не': 
        reloc = True 
    if len(info_strings) > 2 and info_strings[2].split()[0] != 'не': 
        trip = True 
    return pd.Series([city, reloc, trip]) 
df[['Город', 'Готовность к переезду', 'Готовность к командировкам']] = df['Город, переезд, командировки'].apply(city_reloc_trip)

df.drop('Город, переезд, командировки', axis=1, inplace=True)

# Вывод первых строк для проверки
df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
# ...

# %%
df['Город'].value_counts()
# Out:
# Москва              16621
# другие              15854
# город-миллионник     7332
# Санкт-Петербург      4937
# Name: Город, dtype: int64

# %%
df['Готовность к переезду'].value_counts()
# Out:
# False    28719
# True     16025
# Name: Готовность к переезду, dtype: int64

# %%
df['Готовность к командировкам'].value_counts()
# Out:
# True     31647
# False    13097
# Name: Готовность к командировкам, dtype: int64

# %%
# Подсчет количества соискателей в Санкт-Петербурге
spb_resumes = df[df['Город'] == 'Санкт-Петербург'].shape[0]

# Расчет процента соискателей в Санкт-Петербурге
percentage_spb = (spb_resumes / df.shape[0]) * 100

# Округление до целого числа
percentage_spb_rounded = round(percentage_spb)

percentage_spb_rounded
# Out:
# 11

# %%
# Фильтрация соискателей, готовых и к переездам, и к командировкам
ready_for_both = df[(df['Готовность к переезду'] == True) & (df['Готовность к командировкам'] == True)].shape[0]

# Расчет процента
percentage_ready_for_both = (ready_for_both / df.shape[0]) * 100

# Округление до целого числа
percentage_rounded = round(percentage_ready_for_both)

percentage_rounded
# Out:
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
# Список всех категорий для занятости и графика
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Функция для преобразования столбца в one-hot-encoding
def one_hot_encode(column, categories):
    for category in categories:
        df[category] = column.apply(lambda x: category in x if pd.notnull(x) else False)

# Применяем функцию к столбцам 'Занятость' и 'График'
one_hot_encode(df['Занятость'], employment_categories)
one_hot_encode(df['График'], schedule_categories)

# Теперь df содержит новые столбцы с булевыми значениями для каждой категории

# %%
df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
# ...

# %%
# Подсчитаем количество людей, ищущих и проектную работу, и волонтерство
count_project_volunteer = df[(df['проектная работа'] == True) & (df['волонтерство'] == True)].shape[0]

count_project_volunteer
# Out:
# 436

# %%
# Подсчитаем количество людей, которые хотят работать вахтовым методом и с гибким графиком
count_rotational_flexible = df[(df['вахтовый метод'] == True) & (df['гибкий график'] == True)].shape[0]

count_rotational_flexible
# Out:
# 2311

# %%
# Удалим исходные столбцы "Занятость" и "График" из DataFrame
df.drop(['Занятость', 'График'], axis=1, inplace=True)
df.head()  # Покажем первые несколько строк обновленного DataFrame для проверки
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %%
df['ЗП'].value_counts()
# Out:
# 50000 руб.    4064
# 40000 руб.    3762
# 30000 руб.    3264
# 60000 руб.    3087
# 70000 руб.    2388
#               ...
# 14525 руб.       1
# 14900 руб.       1
# 36500 руб.       1
# 4860 USD         1
# 259999 KZT       1
# Name: ЗП, Length: 690, dtype: int64

# %%
df.columns
# Out:
# Index(['ЗП', 'Ищет работу на должность:', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Обновление резюме', 'Авто',
#        'Образование', 'Пол', 'Возраст', 'Опыт работы (месяц)', 'Город',
#        'Готовность к переезду', 'Готовность к командировкам',
#        'полная занятость', 'частичная занятость', 'проектная работа',
#        'волонтерство', 'стажировка', 'полный день', 'сменный график',
#        'гибкий график', 'удаленная работа', 'вахтовый метод'],
#       dtype='object')

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
# Загрузим таблицу с курсами валют
exchange_rates_path = "C:/Users/ekart/OneDrive/Рабочий стол/final_hw_python/ExchangeRates.csv"
exchange_rates = pd.read_csv(exchange_rates_path)

# Проверим первые несколько строк таблицы с курсами валют
exchange_rates.head()
# Out:
#   currency per      date   time    close  vol  proportion
# 0      USD   D  29/12/17  00:00  57.6291    0           1
# 1      USD   D  30/12/17  00:00  57.6002    0           1
# 2      USD   D  31/12/17  00:00  57.6002    0           1
# 3      USD   D  01/01/18  00:00  57.6002    0           1
# 4      USD   D  02/01/18  00:00  57.6002    0           1

# %%
df.columns
# Out:
# Index(['ЗП', 'Ищет работу на должность:', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Обновление резюме', 'Авто',
#        'Образование', 'Пол', 'Возраст', 'Опыт работы (месяц)', 'Город',
#        'Готовность к переезду', 'Готовность к командировкам',
#        'полная занятость', 'частичная занятость', 'проектная работа',
#        'волонтерство', 'стажировка', 'полный день', 'сменный график',
#        'гибкий график', 'удаленная работа', 'вахтовый метод'],
#       dtype='object')

# %%
# Разделим зп
def extract_salary(value):
    salar_words = value.split(' ')
    amount = float(salar_words[0])
    return amount

# Переведем в стандарт
def currency_iso(value):
    currency_map = {
        'USD': 'USD', 
        'KZT': 'KZT',
        'грн': 'UAH', 
        'белруб': 'BYN',
        'EUR': 'EUR', 
        'KGS': 'KGS',
        'сум': 'UZS',
        'AZN': 'AZN',
        'руб': 'RUB'
    }
    currency = value.split(' ')[1].replace('.', '')
    return currency_map.get(currency, 'RUB')

# Загрузка данных об обменных курсах
exchange_rates['date'] = pd.to_datetime(exchange_rates['date'], dayfirst=True).dt.date

#подготовка основных данных

df['Resume Updated'] = pd.to_datetime(df['Обновление резюме'], dayfirst=True).dt.date
df['Salary Amount'] = df['ЗП'].apply(extract_salary)
df['Currency'] = df['ЗП'].apply(currency_iso)

# Объединение данных с учетом курсов валют
salary_data = df.merge(
    exchange_rates, 
    left_on=['Currency', 'Resume Updated'],
    right_on=['currency', 'date'], 
    how='left'
)
salary_data['close'] = salary_data['close'].fillna(1)
salary_data['proportion'] = salary_data['proportion'].fillna(1)
df['ЗП (руб)'] = salary_data['close'] * salary_data['Salary Amount'] / salary_data['proportion']

# Удаление временных столбцов
df = df.drop(['ЗП', 'Salary Amount', 'Currency', 'Resume Updated'], axis=1)

# Расчет медианной ЗП в рублях
median_salary_rub = df['ЗП (руб)'].median()
median_salary_rub
# Out:
# 59019.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %%
df.columns
# Out:
# Index(['Ищет работу на должность:', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Обновление резюме', 'Авто',
#        'Образование', 'Пол', 'Возраст', 'Опыт работы (месяц)', 'Город',
#        'Готовность к переезду', 'Готовность к командировкам',
#        'полная занятость', 'частичная занятость', 'проектная работа',
#        'волонтерство', 'стажировка', 'полный день', 'сменный график',
#        'гибкий график', 'удаленная работа', 'вахтовый метод', 'ЗП (руб)'],
#       dtype='object')

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Подготовка данных и визуализация

# Построение гистограммы и коробчатой диаграммы для возраста
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Гистограмма
sns.histplot(df['Возраст'], bins=30, kde=False, ax=ax[0])
ax[0].set_title('Гистограмма Возраста')
ax[0].set_xlabel('Возраст')
ax[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(x=df['Возраст'], ax=ax[1])
ax[1].set_title('Коробчатая Диаграмма Возраста')
ax[1].set_xlabel('Возраст')

plt.tight_layout()
plt.show()

# Анализ данных

# Мода распределения
age_mode = df['Возраст'].mode()[0]

# Предельные значения возраста
age_min = df['Возраст'].min()
age_max = df['Возраст'].max()

# Аномалии: возраст менее 16 лет и более 70 лет
age_anomalies_below_16 = df[df['Возраст'] < 16].shape[0]
age_anomalies_above_70 = df[df['Возраст'] > 70].shape[0]

# Выводы
(age_mode, age_min, age_max, age_anomalies_below_16, age_anomalies_above_70)
# Out:
# (30, 14, 100, 3, 14)

# %% [markdown]
# # ваши выводы по графику здесь
#
# Мода распределения:
#
# * Самый частый возраст соискателей - 30 лет.
#
# Предельные значения возраста:
# * Минимальный возраст соискателей составляет 14 лет, что является необычно низким для трудоустройства и может указывать на ошибку в данных.
# * Максимальный возраст - 100 лет, что также выглядит как аномалия, поскольку обычно люди такого возраста не ищут работу.
#
# Интервал возрастов большинства соискателей:
#
# * 25-й процентиль - 27 лет, что означает, что 25% соискателей младше 27 лет.
# * Медиана (50-й процентиль) - 31 год, следовательно, половина соискателей находится в возрасте до 31 года.
# * 75-й процентиль - 36 лет, то есть 75% соискателей младше 36 лет.
#
# Аномалии в данных:
#
# * Найдено 3 случая, где возраст соискателей меньше 16 лет, что является аномальным для категории соискателей работы.
# * Обнаружено 14 случаев, где возраст соискателей превышает 70 лет, что также можно рассматривать как аномалии.
#
#
# Графики:
#
# * Гистограмма показывает, что распределение возраста перекошено влево, что свидетельствует о большем числе молодых соискателей по сравнению с более старшими.
#
# * Коробчатая диаграмма подтверждает наличие аномалий в данных: множество значений, превышающих верхний «ус» диаграммы, предположительно указывает на редкие случаи очень высокого возраста, которые выходят за рамки типичного диапазона для трудоустройства. В то же время значение возраста в 14 лет также выглядит как выброс.
#
# Таким образом, данные по возрасту содержат значения, которые могут быть классифицированы как аномалии. В нормальных условиях трудовой деятельности ожидается, что соискатели будут в возрасте от около 16 до 70 лет. Возрастные значения за пределами этого диапазона, как правило, считаются нестандартными для анализа рынка труда и могут потребовать дополнительного исследования

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построим гистограмму и коробчатую диаграмму для признака "Опыт работы (месяц)"
plt.figure(figsize=(15, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(df['Опыт работы (месяц)'], bins=30, kde=True)
plt.title('Гистограмма опыта работы (в месяцах)')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(df['Опыт работы (месяц)'])
plt.title('Коробчатая диаграмма опыта работы')
plt.xlabel('Опыт работы (месяц)')

plt.tight_layout()
plt.show()

# Расчет основных статистик
basic_stats = df['Опыт работы (месяц)'].describe()
mode = df['Опыт работы (месяц)'].mode()[0]
basic_stats, mode
# Out:
# (count    44574.000000
#  mean       114.418944
#  std         79.047861
#  min          1.000000
#  25%         57.000000
#  50%        100.000000
#  75%        154.000000
#  max       1188.000000
#  Name: Опыт работы (месяц), dtype: float64,
#  81.0)

# %% [markdown]
# # ваши выводы здесь
#
# Гистограмма и коробчатая диаграмма для признака "Опыт работы (месяц)" показывают следующее:
#
# Мода распределения:
# * Самый часто встречающийся опыт работы среди соискателей составляет 81 месяц.
#
# Предельные значения признака:
#
# * Минимальный опыт работы: 1 месяц.
# * Максимальный опыт работы: 1188 месяцев (что составляет примерно 99 лет, что выглядит аномально).
#
# Интервал опыта работы большинства соискателей:
#
# * 25% соискателей имеют опыт работы до 57 месяцев.
# * Медиана (50%) находится на уровне 100 месяцев, что означает, что половина соискателей имеет опыт работы до 100 месяцев.
# * 75% соискателей имеют опыт работы до 154 месяцев.
#
# Аномалии в признаке опыта работы:
#
# * На коробчатой диаграмме видны выбросы, указывающие на аномально высокий опыт работы некоторых соискателей.
# * Максимальное значение в 1188 месяцев явно выходит за рамки обычных значений и может быть рассмотрено как аномалия.
# Т
# аким образом, большинство соискателей имеют опыт работы в диапазоне от 1 до 154 месяцев, при этом наиболее часто встречаемое значение — 81 месяц. Аномальные значения, такие как 1188 месяцев опыта работы, могут быть результатом ошибок в данных или чрезвычайно редких случаев.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Установим верхнюю границу для гистограммы, чтобы лучше увидеть распределение основной массы заработных плат
max_salary_limit = df['ЗП (руб)'].quantile(0.95)
filtered_salary = df[df['ЗП (руб)'] <= max_salary_limit]['ЗП (руб)']

fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Гистограмма с ограниченной верхней границей
sns.histplot(filtered_salary, bins=30, kde=False, ax=ax[0])
ax[0].set_title('Гистограмма Желаемой Заработной Платы (до 95-го перцентиля)')
ax[0].set_xlabel('Заработная плата (руб)')
ax[0].set_ylabel('Частота')

# Коробчатая диаграмма без ограничения
# Она покажет общую картину, включая аномальные значения
sns.boxplot(x=df['ЗП (руб)'].dropna(), ax=ax[1])
ax[1].set_title('Коробчатая Диаграмма Заработной Платы')
ax[1].set_xlabel('Заработная плата (руб)')

plt.tight_layout()
plt.show()


# Анализ данных

# Предельные значения заработной платы
salary_min = df['ЗП (руб)'].min()
salary_max = df['ЗП (руб)'].max()

# Определение потенциальных аномалий (например, слишком высокая заработная плата)
# Будем считать аномальными значения, значительно превышающие средний уровень
salary_anomalies = df[df['ЗП (руб)'] > df['ЗП (руб)'].quantile(0.99)].shape[0]

# Выводы
(salary_min, salary_max, salary_anomalies)
# Out:
# (1.0, 24304876.0, 331)

# %%
# Построение гистограммы с помощью Plotly Express для визуализации распределения "Опыт работы (месяц)"
fig = px.histogram(df, x="Опыт работы (месяц)", marginal="box", 
                   title="Распределение Опыта Работы (в месяцах) с Коробчатой Диаграммой",
                   labels={"Опыт работы (месяц)": "Опыт работы (месяц)"})
fig.show()

# %%
fig.write_html('C:/Users/ekart/OneDrive/Рабочий стол/final_hw_python/experience_histogram.html')

# %%
# Установим порог, например, в 1 миллион рублей
salary_threshold = 1e6

# Фильтруем данные для улучшения визуализации
filtered_salaries = df[df['ЗП (руб)'] <= salary_threshold]['ЗП (руб)']

plt.figure(figsize=(15, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(filtered_salaries, bins=50, kde=True)
plt.title('Гистограмма желаемой заработной платы (до 1 млн руб)')
plt.xlabel('Заработная плата (руб)')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(filtered_salaries)
plt.title('Коробчатая диаграмма желаемой заработной платы (до 1 млн руб)')
plt.xlabel('Заработная плата (руб)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ваши выводы здесь
#
# Предельные значения признака:
#
# * Минимальная желаемая заработная плата: 1 рубль.
# * Максимальная желаемая заработная плата: 24,304,880 рублей.
#
# Интервал заработной платы большинства соискателей:
#
# * 25% соискателей указали желаемую заработную плату до 37,082.20 рублей.
# * Медиана (50%) находится на уровне 59,019 рублей, что означает, что половина соискателей указала заработную плату менее 59,019 рублей.
# * 75% соискателей указали заработную плату до 95,000 рублей.
#
# Аномалии в признаке "ЗП (руб)":
#
# На коробчатой диаграмме видны значительные выбросы, указывающие на аномально высокие значения желаемой заработной платы.
# Максимальное значение в размере 24,304,880 рублей явно выходит за рамки обычных значений и может быть рассмотрено как аномалия.
# В целом, большинство соискателей указывают желаемую заработную плату в диапазоне от 1 до 95,000 рублей. Однако существуют аномальные значения, такие как максимальная зарплата в размере более 24 миллионов рублей

# %%
# Определим количество соискателей, требующих заработную плату выше 1 миллиона рублей
high_salary_count = df[df['ЗП (руб)'] > 1e6].shape[0]
high_salary_count
# Out:
# 5

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Фильтруем данные, где желаемая заработная плата меньше 1 миллиона рублей
filtered_data = df[df['ЗП (руб)'] < 1e6]

# Группируем данные по уровню образования и вычисляем медианную заработную плату
median_salary_by_education = filtered_data.groupby('Образование')['ЗП (руб)'].median().sort_values()

# Построение диаграммы
plt.figure(figsize=(10, 6))
sns.barplot(x=median_salary_by_education.values, y=median_salary_by_education.index)
plt.title('Зависимость медианной желаемой заработной платы от уровня образования')
plt.xlabel('Медианная заработная плата (руб)')
plt.ylabel('Уровень образования')
plt.show()

# %%
# медианная зарплата для каждого уровня образования
median_salary_by_education = df.groupby('Образование')['ЗП (руб)'].median().sort_values(ascending=False)

# выод реузультатов
median_salary_by_education
# Out:
# Образование
# высшее                 60000.0
# неоконченное высшее    50000.0
# среднее                40000.0
# среднее специальное    40000.0
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# # ваши выводы здесь
#
# * Наибольшие уровни желаемой заработной платы наблюдаются у соискателей с уровнем образования "высшее". Это может быть связано с тем, что более высокий уровень образования часто требует более квалифицированных навыков и знаний, что, в свою очередь, повышает стоимость труда специалиста на рынке.
#
# * Наименьшие уровни желаемой заработной платы наблюдаются у соискателей с уровнем образования "среднее специальное" и "среднее". Это может быть связано с ограниченными возможностями карьерного роста и меньшей конкурентоспособностью на рынке труда по сравнению с более высокими уровнями образования.
#
# Выводы:
#
# * Уровень образования является важным фактором при прогнозировании заработной платы. Высшее образование, как правило, коррелирует с более высокой желаемой заработной платой.
# * Эти данные подчеркивают важность образования в формировании карьерных перспектив и потенциала заработка. ​​

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Отфильтровать данные, чтобы включить только те резюме, где желаемая ЗП меньше 1 млн рублей
filtered_data = df[df['ЗП (руб)'] < 1000000]

# Создание диаграммы распределения желаемой заработной платы по городам
plt.figure(figsize=(15, 8))
sns.boxplot(x='ЗП (руб)', y='Город', data=filtered_data)
plt.title('Распределение желаемой заработной платы по городам')
plt.xlabel('Желаемая заработная плата (руб)')
plt.ylabel('Город')
plt.show()

# %%
# фильтруем зп меньше миллиона
filtered_data = df[df["ЗП (руб)"] < 1000000]

# группируем данные по городу и считаем статистики по желаемой зп
salary_stats_by_city = filtered_data.groupby('Город')['ЗП (руб)'].agg(['median', 'count', 'min', 'max'])
salary_stats_by_city['iqr'] = salary_stats_by_city.apply(lambda row: row['max'] - row['min'], axis=1)

# вывод статистик
salary_stats_by_city.sort_values(by='median', ascending=False)
# Out:
#                    median  count  min       max       iqr
# Город
# Москва            85000.0  16617  1.0  900000.0  899999.0
# Санкт-Петербург   60000.0   4937  1.0  645171.0  645170.0
# город-миллионник  40000.0   7332  1.0  511681.6  511680.6
# другие            40000.0  15852  1.0  923983.0  923982.0

# %%
highest_salary_city = df[df['ЗП (руб)'] == df['ЗП (руб)'].max()]['Город'].unique()

highest_salary_city
# Out:
# array(['другие'], dtype=object)

# %% [markdown]
# # ваши выводы здесь
# * Москва имеет самый высокий медианный уровень желаемой заработной платы, который составляет 85,000 рублей. Это указывает на то, что кандидаты в Москве ожидают более высокую оплату труда, что может быть связано с более высокой стоимостью жизни и большими возможностями для карьерного роста.
#
# * Санкт-Петербург следует за Москвой с медианным уровнем желаемой заработной платы в 60,000 рублей.
#
# * В городах-миллионниках и других городах медианный уровень желаемой заработной платы одинаков и составляет 40,000 рублей, что значительно ниже, чем в двух крупнейших городах страны.
#
# * Размах желаемой заработной платы (разница между максимальной и минимальной запрашиваемой заработной платой) наибольший в Москве и других городах, что указывает на большое разнообразие ожиданий кандидатов по уровню зарплаты. Это может быть связано с разнообразием рабочих мест и различиями в уровне квалификации кандидатов плюс с более дорогим уровнем жизни.
#
# В заключение следует отметить, что город является важным фактором, определяющим желаемую зарплату, поскольку он отражает экономические условия, стоимость жизни и конкуренцию на рынке труда в данном регионе.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь

# группируем данные 'Готовность к переезду'и 'Готовность к командировкам' и считаем медианную зп
salary_by_relocation_and_business_trips = df.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().reset_index()

# делаем пивот
pivot_table = salary_by_relocation_and_business_trips.pivot(index='Готовность к переезду', columns='Готовность к командировкам', values='ЗП (руб)')

# multilevel bar plot
fig, ax = plt.subplots(figsize=(10, 6))
pivot_table.plot(kind='bar', ax=ax)
plt.title('Зависимость медианной заработной платы от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб)')
plt.xticks(rotation=0)
plt.legend(title='Готовность к командировкам')
plt.tight_layout()
plt.show()

# %%
median_salary_relocate_travel = df[(df['Готовность к переезду'] == True) & (df['Готовность к командировкам'] == True)]['ЗП (руб)'].median()

# Converting to thousands and rounding to the nearest whole number
median_salary_relocate_travel_thousands = round(median_salary_relocate_travel / 1000)

median_salary_relocate_travel_thousands
# Out:
# 66

# %% [markdown]
# # ваши выводы здесь
#
# * Многоуровневая гистограмма иллюстрирует связь между медианной желаемой зарплатой и готовностью к переезду и командировкам. Вот анализ диаграммы:
#
# * Кандидаты, которые готовы и переехать, и отправиться в командировку, имеют самую высокую медианную желаемую зарплату.
# * Готовность к командировкам, похоже, оказывает большее влияние на медианную желаемую зарплату, чем готовность к переезду. Это очевидно, поскольку в обеих категориях готовности к переезду (правда или ложь) кандидаты, готовые отправиться в командировку, имеют более высокую медианную зарплату, чем те, кто не готов к этому.
# * Медианная желаемая зарплата кандидатов, готовых переехать, но не желающих ехать в командировку, несколько выше, чем у тех, кто не готов переезжать и не желает ехать в командировку.
#
#
# Интересно, что готовность к переезду без готовности к командировкам, похоже, не приводит к значительному увеличению медианной желаемой зарплаты.
# Из этого можно сделать вывод, что гибкость в выборе места работы и готовность к командировкам ценятся на рынке труда и потенциально могут привести к более высоким зарплатным ожиданиям. Работодатели могут рассматривать готовность к командировкам как признак гибкости и целеустремленности кандидата, что может объяснить повышение медианной зарплаты таких кандидатов.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь

pivot_table = df.pivot_table(values='ЗП (руб)', index='Образование', columns='Возраст', aggfunc='median')

# Plotting the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='viridis')
plt.title('Heatmap of Median Desired Salary by Age and Education')
plt.xlabel('Age')
plt.ylabel('Education')
plt.show()

# %% [markdown]
# # ваши выводы здесь
#
# * Тепловая карта иллюстрирует зависимость медианной желаемой зарплаты от возраста и образования. Вот несколько ключевых наблюдений:
#
# * Различия между возрастами: В большинстве категорий образования наблюдается заметный рост медианной желаемой зарплаты с увеличением возраста. Эта тенденция свидетельствует о карьерном росте и накоплении опыта с течением времени.
#
# * Влияние образования: Различные категории образования демонстрируют разный уровень заработной платы. Например, в некоторых категориях образования зарплата в определенном возрасте выше, чем в других.
#
# * Возраст пиковой зарплаты: В некоторых категориях образования существует пиковый возрастной диапазон, в котором зарплаты наиболее высоки, что может отражать лучшие годы для карьерного роста в этих областях.
#
# * Сравнение по уровням образования: Существуют заметные различия в ожидаемой заработной плате для разных уровней образования. Более высокие уровни образования, как правило, соответствуют более высоким зарплатным ожиданиям, но на это также влияет возраст.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
# Перевод опыта работы из месяцев в годы
df["Опыт работы (год)"] = df["Опыт работы (месяц)"] / 12

# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(df["Возраст"], df["Опыт работы (год)"], alpha=0.6, label='Данные')

# Добавление прямой, проходящей через точки (0, 0) и (100, 100)
plt.plot([0, 100], [0, 100], color='red', label='Опыт = Возраст')

# Настройка графика
plt.xlabel('Возраст')
plt.ylabel('Опыт работы (год)')
plt.title('Зависимость опыта работы от возраста')
plt.legend()
plt.grid(True)

# Показ графика
plt.show()

# %%
points_above_line = (df["Опыт работы (год)"] > df["Возраст"]).sum()

points_above_line
# Out:
# 7

# %% [markdown]
# # ваши выводы здесь
#
# На загруженном вами графике видно, что большинство точек сосредоточено под красной линией, что означает, что для большинства соискателей опыт работы меньше их возраста, что является ожидаемым результатом. Есть несколько точек, расположенных очень близко к линии или над ней, что может указывать на аномалии в данных или на очень раннее начало карьеры.
#
# Также видно, что с увеличением возраста опыт работы тенденциозно увеличивается, что также соответствует ожиданиям, так как чем старше человек, тем больше у него времени было для накопления опыта работы.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
# Гистограмма распределения опыта работы соискателей (в годах)
plt.figure(figsize=(10, 6))
plt.hist(df['Опыт работы (год)'], bins=range(int(df['Опыт работы (год)'].min()), int(df['Опыт работы (год)'].max()) + 1, 5), color='lightgreen', edgecolor='black')
plt.title('Распределение опыта работы (в годах)')
plt.xlabel('Опыт работы (год)')
plt.ylabel('Количество соискателей')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# зп от возраста и согласию к переезду
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Возраст', y='ЗП (руб)', hue='Готовность к переезду', alpha=0.6)
plt.title('Желаемая Заработная Плата vs Возраст и Готовность к Переезду')
plt.xlabel('Возраст')
plt.ylabel('Желаемая Заработная Плата (руб)')
plt.legend(title='Готовность к Переезду')
plt.grid(True)

# зарплата от опыта работы
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Опыт работы (год)', y='ЗП (руб)', alpha=0.6)
plt.title('Желаемая Заработная Плата vs Опыт Работы')
plt.xlabel('Опыт работы (год)')
plt.ylabel('Желаемая Заработная Плата (руб)')
plt.grid(True)

plt.show()

# %% [markdown]
# # ваши выводы здесь
#
# * Больше всего соискатателей по опыту работы содержатся в диапазоне от 0 до 20 лет
# * требования по зп больше у тех кто готов к переезду)

# %% [markdown]
# # Очистка данных

# %%
df = df.drop(['Опыт работы (год)'], axis=1)

# %%
df
# Out:
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# 2                                               Оператор
# 3      Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                      Региональный менеджер по продажам
# ...                                                  ...
# 44739  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740             Системный администратор, IT-специалист
# 44741                         Аналитик данных, Математик
# 44742                                   Контент-менеджер
# 44743                               Руководитель проекта
#
#                          Последнее/нынешнее место работы  \
# 0                                МАОУ "СОШ № 1 г.Немана"
# 1                           Временный трудовой коллектив
# 2                                           ПАО Сбербанк
# ...

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
initial_count = df.shape[0]
df_deduplicated = df.drop_duplicates()
final_count = df_deduplicated.shape[0]

# количество полных дубликатов
number_of_duplicates = initial_count - final_count
number_of_duplicates
# Out:
# 158

# %% [markdown]
# куда делось еще 3 я не знаю, перелопатил уже все

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
# Проверяем пропуски в каждой колонке
missing_values = df_deduplicated.isnull().sum()
missing_values_experience = missing_values["Опыт работы (месяц)"]
missing_values_experience
# Out:
# 168

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
# убираем строки с пропусками в 'Последнее/нынешнее место работы' и 'Последняя/нынешняя должность'
df_cleaned = df_deduplicated.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполняем пропущенные значения 'Опыт работы (месяц)' медианой
experience_median = df_cleaned['Опыт работы (месяц)'].median()
df_cleaned['Опыт работы (месяц)'].fillna(experience_median, inplace=True)

# проверка 
missing_values_after_cleaning = df_cleaned.isnull().sum()
missing_values_after_cleaning
# Out:
# C:\Users\ekart\AppData\Local\Temp\ipykernel_25464\4090449731.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Ищет работу на должность:          0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# Обновление резюме                  0
# Авто                               0
# Образование                        0
# Пол                                0
# Возраст                            0
# Опыт работы (месяц)                0
# Город                              0
# Готовность к переезду              0
# Готовность к командировкам         0
# полная занятость                   0
# частичная занятость                0
# проектная работа                   0
# волонтерство                       0
# стажировка                         0
# ...

# %%
mean_experience = df_cleaned['Опыт работы (месяц)'].mean()
rounded_mean_experience = round(mean_experience)
rounded_mean_experience
# Out:
# 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
# Убираем резюме с зп больше 1,000,000 или меньше 1,000 рублей
df_no_outliers = df_cleaned[(df_cleaned['ЗП (руб)'] <= 1000000) & (df_cleaned['ЗП (руб)'] >= 1000)]

# Подсчет количество удаленных строк
rows_removed = df_cleaned.shape[0] - df_no_outliers.shape[0]
rows_removed, df_no_outliers.shape[0]
# Out:
# (89, 44495)

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
# Cопыт в месяцах в год
df_no_outliers['Опыт работы (год)'] = df_no_outliers['Опыт работы (месяц)'] / 12

# опыт работы превышает возраст
df_realistic = df_no_outliers[df_no_outliers['Опыт работы (год)'] <= df_no_outliers['Возраст']]

# число удаленных наблюдений
rows_removed_unrealistic = df_no_outliers.shape[0] - df_realistic.shape[0]
rows_removed_unrealistic, df_realistic.shape[0]
# Out:
# C:\Users\ekart\AppData\Local\Temp\ipykernel_25464\4234254096.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (7, 44488)

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь
from scipy.stats import zscore
# Логарифмическое преобразование признака 'Возраст'
log_age = np.log(df_realistic['Возраст'])

# Построение графика распределения
plt.figure(figsize=(10, 6))
histplot = sns.histplot(log_age, kde=True)
histplot.axvline(log_age.mean(), color='k', lw=2)  # Линия среднего значения

# Расчет среднего и стандартного отклонения для логарифмически преобразованного возраста
mean_log_age = log_age.mean()
std_log_age = log_age.std()

# Рисование линий для метода трех сигм (с допуском в 4 сигмы вправо)
histplot.axvline(mean_log_age - 3 * std_log_age, color='r', linestyle='--', lw=2)  # Нижняя граница
histplot.axvline(mean_log_age + 4 * std_log_age, color='r', linestyle='--', lw=2)  # Верхняя граница

# Добавление заголовка и меток
plt.title('Логарифмическое распределение возраста с линиями среднего и границ трех сигм')
plt.xlabel('Логарифм(Возраст)')
plt.ylabel('Частота')

# Комментарий о скошенности распределения
plt.text(mean_log_age + 0.5, 50, 'Распределение скошено вправо', fontsize=12, color='blue')

plt.show()

# Выявление выбросов с использованием z-оценки (с допуском в 4 сигмы вправо)
z_scores = zscore(log_age)
outliers = df_realistic[(z_scores < -3) | (z_scores > 4)]

# Отображение таблицы с выбросами
outliers[['Возраст']].head()  # Выводим первые несколько строк для краткости
# Out:
#        Возраст
# 31137       15
# 32950       15
# 33654      100

# %% [markdown]
# # ваш коммментарий здесь
#
# На графике представлено логарифмическое распределение возраста соискателей с линиями, обозначающими среднее значение и границы интервала по методу трех сигм (с послаблением до 4 сигм в правую сторону). Распределение является асимметричным вправо, что указано в комментарии на графике.
#
# После применения метода z-отклонения с учетом логарифмического масштаба и послабления до 4 сигм справа, были обнаружены выбросы. В таблице выбросов видно, что категорию выбросов составляют соискатели с возрастом 15 и 100 лет. ​

# %%
# Подсчет количества выбросов, найденных с помощью метода z-отклонений
number_of_outliers = outliers.shape[0]
number_of_outliers
# Out:
# 3
